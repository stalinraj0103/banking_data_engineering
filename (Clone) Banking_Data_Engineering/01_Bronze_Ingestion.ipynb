# %%
# %python
customers_df = spark.read \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .csv("/Volumes/workspace/default/banking_raw/banking_project_dataset/banking_project_dataset/customers_raw.csv")

# %%
# %python
customers_df.show(10)
# Out:
# +-----------+---------------+--------------------+---+---------+-----------+-----------------+
# |customer_id|  customer_name|               email|age|     city|      state|registration_date|
# +-----------+---------------+--------------------+---+---------+-----------+-----------------+
# |    C000001|Customer_000001|customer000001@ex...| 30|  Madurai| Tamil Nadu|       2024-03-07|
# |    C000002|Customer_000002|customer000002@ex...| 20|    Kochi|     Kerala|       2025-12-01|
# |    C000003|Customer_000003|customer000003@ex...| 40|    Salem| Tamil Nadu|       2024-11-26|
# |    C000004|Customer_000004|customer000004@ex...| 28| Thrissur|     Kerala|       2025-10-30|
# |    C000005|Customer_000005|customer000005@ex...| 36|New Delhi|      Delhi|       2024-07-06|
# |    C000006|Customer_000006|customer000006@ex...| 36|    Kochi|     Kerala|       2024-01-10|
# |    C000007|Customer_000007|customer000007@ex...| 62|New Delhi|      Delhi|       2024-05-03|
# |    C000008|Customer_000008|customer000008@ex...| 36| Warangal|  Telangana|       2025-02-27|
# |    C000009|Customer_000009|customer000009@ex...| 26|     Pune|Maharashtra|       2025-03-07|
# |    C000010|Customer_000010|customer000010@ex...| 72| Warangal|  Telangana|       2025-01-28|
# +-----------+---------------+--------------------+---+---------+-----------+-----------------+
# only showing top 10 rows

# %%
# %python
customers_df.printSchema()
# Out:
# root
#  |-- customer_id: string (nullable = true)
#  |-- customer_name: string (nullable = true)
#  |-- email: string (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- city: string (nullable = true)
#  |-- state: string (nullable = true)
#  |-- registration_date: date (nullable = true)

# %%
# %python
print("Customer records:", customers_df.count())
# Out:
# Customer records: 12030

# %%
# %python
print(customers_df.columns)
# Out:
# ['customer_id', 'customer_name', 'email', 'age', 'city', 'state', 'registration_date']

# %%
# %python
customers_df.show(10)
customers_df.printSchema()
print("Customer records:", customers_df.count())
# Out:
# +-----------+---------------+--------------------+---+---------+-----------+-----------------+
# |customer_id|  customer_name|               email|age|     city|      state|registration_date|
# +-----------+---------------+--------------------+---+---------+-----------+-----------------+
# |    C000001|Customer_000001|customer000001@ex...| 30|  Madurai| Tamil Nadu|       2024-03-07|
# |    C000002|Customer_000002|customer000002@ex...| 20|    Kochi|     Kerala|       2025-12-01|
# |    C000003|Customer_000003|customer000003@ex...| 40|    Salem| Tamil Nadu|       2024-11-26|
# |    C000004|Customer_000004|customer000004@ex...| 28| Thrissur|     Kerala|       2025-10-30|
# |    C000005|Customer_000005|customer000005@ex...| 36|New Delhi|      Delhi|       2024-07-06|
# |    C000006|Customer_000006|customer000006@ex...| 36|    Kochi|     Kerala|       2024-01-10|
# |    C000007|Customer_000007|customer000007@ex...| 62|New Delhi|      Delhi|       2024-05-03|
# |    C000008|Customer_000008|customer000008@ex...| 36| Warangal|  Telangana|       2025-02-27|
# |    C000009|Customer_000009|customer000009@ex...| 26|     Pune|Maharashtra|       2025-03-07|
# |    C000010|Customer_000010|customer000010@ex...| 72| Warangal|  Telangana|       2025-01-28|
# +-----------+---------------+--------------------+---+---------+-----------+-----------------+
# only showing top 10 rows
# root
#  |-- customer_id: string (nullable = true)
#  |-- customer_name: string (nullable = true)
#  |-- email: string (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- city: string (nullable = true)
#  |-- state: string (nullable = true)
#  |-- registration_date: date (nullable = true)
#
# Customer records: 12030

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS banking_bronze;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS workspace.banking_bronze;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %python
spark.catalog.listTables("workspace.banking_bronze")
# Out:
# []

# %%
# %python
customers_df = spark.read \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .csv("/Volumes/workspace/default/banking_raw/banking_project_dataset/banking_project_dataset/customers_raw.csv")

# %%
# %python
customers_df.count()
# Out:
# 12030

# %%
# %python
customers_df.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("workspace.banking_bronze.customers")

# %%
# %python
spark.table("workspace.banking_bronze.customers").count()
# Out:
# 12030

# %%
# %python
spark.table("workspace.banking_bronze.customers").show(5)
# Out:
# +-----------+---------------+--------------------+---+---------+----------+-----------------+
# |customer_id|  customer_name|               email|age|     city|     state|registration_date|
# +-----------+---------------+--------------------+---+---------+----------+-----------------+
# |    C000001|Customer_000001|customer000001@ex...| 30|  Madurai|Tamil Nadu|       2024-03-07|
# |    C000002|Customer_000002|customer000002@ex...| 20|    Kochi|    Kerala|       2025-12-01|
# |    C000003|Customer_000003|customer000003@ex...| 40|    Salem|Tamil Nadu|       2024-11-26|
# |    C000004|Customer_000004|customer000004@ex...| 28| Thrissur|    Kerala|       2025-10-30|
# |    C000005|Customer_000005|customer000005@ex...| 36|New Delhi|     Delhi|       2024-07-06|
# +-----------+---------------+--------------------+---+---------+----------+-----------------+
# only showing top 5 rows

# %%
# %python
customers_df
# Out:
# DataFrame[customer_id: string, customer_name: string, email: string, age: int, city: string, state: string, registration_date: date]

# %%
# %python
customers_df = spark.read \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .csv("/Volumes/workspace/default/banking_raw/banking_project_dataset/banking_project_dataset/customers_raw.csv")

# %%
# %python
customers_df.count()
# Out:
# 12030

# %%
# %python
customers_df.show(5)
# Out:
# +-----------+---------------+--------------------+---+---------+----------+-----------------+
# |customer_id|  customer_name|               email|age|     city|     state|registration_date|
# +-----------+---------------+--------------------+---+---------+----------+-----------------+
# |    C000001|Customer_000001|customer000001@ex...| 30|  Madurai|Tamil Nadu|       2024-03-07|
# |    C000002|Customer_000002|customer000002@ex...| 20|    Kochi|    Kerala|       2025-12-01|
# |    C000003|Customer_000003|customer000003@ex...| 40|    Salem|Tamil Nadu|       2024-11-26|
# |    C000004|Customer_000004|customer000004@ex...| 28| Thrissur|    Kerala|       2025-10-30|
# |    C000005|Customer_000005|customer000005@ex...| 36|New Delhi|     Delhi|       2024-07-06|
# +-----------+---------------+--------------------+---+---------+----------+-----------------+
# only showing top 5 rows

# %%
# %python
customers_df = spark.read \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .csv("/Volumes/workspace/default/banking_raw/banking_project_dataset/banking_project_dataset/customers_raw.csv")

# %%
# %python
customers_df.count()
# Out:
# 12030

# %%
# %python
customers_df.show(5)
# Out:
# +-----------+---------------+--------------------+---+---------+----------+-----------------+
# |customer_id|  customer_name|               email|age|     city|     state|registration_date|
# +-----------+---------------+--------------------+---+---------+----------+-----------------+
# |    C000001|Customer_000001|customer000001@ex...| 30|  Madurai|Tamil Nadu|       2024-03-07|
# |    C000002|Customer_000002|customer000002@ex...| 20|    Kochi|    Kerala|       2025-12-01|
# |    C000003|Customer_000003|customer000003@ex...| 40|    Salem|Tamil Nadu|       2024-11-26|
# |    C000004|Customer_000004|customer000004@ex...| 28| Thrissur|    Kerala|       2025-10-30|
# |    C000005|Customer_000005|customer000005@ex...| 36|New Delhi|     Delhi|       2024-07-06|
# +-----------+---------------+--------------------+---+---------+----------+-----------------+
# only showing top 5 rows

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS workspace.banking_bronze;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
customers_df = spark.read \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .csv("/Volumes/workspace/default/banking_raw/banking_project_dataset/banking_project_dataset/customers_raw.csv")

print("Records:", customers_df.count())

customers_df.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("workspace.banking_bronze.customers")

print("Bronze customers table created successfully!")
# Out:
# Records: 12030
# Bronze customers table created successfully!

# %%
spark.table("workspace.banking_bronze.customers").count()
# Out:
# 12030

# %%
spark.table("workspace.banking_bronze.customers").show(5)
# Out:
# +-----------+---------------+--------------------+---+---------+----------+-----------------+
# |customer_id|  customer_name|               email|age|     city|     state|registration_date|
# +-----------+---------------+--------------------+---+---------+----------+-----------------+
# |    C000001|Customer_000001|customer000001@ex...| 30|  Madurai|Tamil Nadu|       2024-03-07|
# |    C000002|Customer_000002|customer000002@ex...| 20|    Kochi|    Kerala|       2025-12-01|
# |    C000003|Customer_000003|customer000003@ex...| 40|    Salem|Tamil Nadu|       2024-11-26|
# |    C000004|Customer_000004|customer000004@ex...| 28| Thrissur|    Kerala|       2025-10-30|
# |    C000005|Customer_000005|customer000005@ex...| 36|New Delhi|     Delhi|       2024-07-06|
# +-----------+---------------+--------------------+---+---------+----------+-----------------+
# only showing top 5 rows

# %%
spark.table("workspace.banking_bronze.customers").count()
# Out:
# 12030

# %%
accounts_df = spark.read \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .csv("/Volumes/workspace/default/banking_raw/banking_project_dataset/banking_project_dataset/accounts_raw.csv")

print("Account records:", accounts_df.count())

accounts_df.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("workspace.banking_bronze.accounts")

print("Bronze accounts table created!")
# Out:
# Account records: 15030
# Bronze accounts table created!

# %%
spark.table("workspace.banking_bronze.accounts").count()
# Out:
# 15030

# %%
transactions_df = spark.read \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .csv("/Volumes/workspace/default/banking_raw/banking_project_dataset/banking_project_dataset/transactions_raw.csv")

print("Transaction records:", transactions_df.count())

transactions_df.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("workspace.banking_bronze.transactions")

print("Bronze transactions table created!")
# Out:
# Transaction records: 50150
# Bronze transactions table created!

# %%
spark.table("workspace.banking_bronze.transactions").count()
# Out:
# 50150

# %%
spark.table("workspace.banking_bronze.transactions").printSchema()
# Out:
# root
#  |-- transaction_id: string (nullable = true)
#  |-- account_id: string (nullable = true)
#  |-- transaction_date: date (nullable = true)
#  |-- transaction_type: string (nullable = true)
#  |-- amount: double (nullable = true)
#  |-- payment_method: string (nullable = true)
#  |-- merchant_id: string (nullable = true)
#  |-- status: string (nullable = true)

# %%
branches_df = spark.read \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .csv("/Volumes/workspace/default/banking_raw/banking_project_dataset/banking_project_dataset/branches_raw.csv")

print("Branch records:", branches_df.count())

branches_df.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("workspace.banking_bronze.branches")

print("Bronze branches table created!")
# Out:
# Branch records: 105
# Bronze branches table created!

# %%
spark.table("workspace.banking_bronze.branches").count()
# Out:
# 105

# %%
merchants_df = spark.read \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .csv("/Volumes/workspace/default/banking_raw/banking_project_dataset/banking_project_dataset/merchants_raw.csv")

print("Merchant records:", merchants_df.count())

merchants_df.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("workspace.banking_bronze.merchants")

print("Bronze merchants table created!")
# Out:
# Merchant records: 2020
# Bronze merchants table created!

# %%
spark.table("workspace.banking_bronze.merchants").count()
# Out:
# 2020

# %%
customers_bronze = spark.table("workspace.banking_bronze.customers")

customers_bronze.show(5)
# Out:
# +-----------+---------------+--------------------+---+---------+----------+-----------------+
# |customer_id|  customer_name|               email|age|     city|     state|registration_date|
# +-----------+---------------+--------------------+---+---------+----------+-----------------+
# |    C000001|Customer_000001|customer000001@ex...| 30|  Madurai|Tamil Nadu|       2024-03-07|
# |    C000002|Customer_000002|customer000002@ex...| 20|    Kochi|    Kerala|       2025-12-01|
# |    C000003|Customer_000003|customer000003@ex...| 40|    Salem|Tamil Nadu|       2024-11-26|
# |    C000004|Customer_000004|customer000004@ex...| 28| Thrissur|    Kerala|       2025-10-30|
# |    C000005|Customer_000005|customer000005@ex...| 36|New Delhi|     Delhi|       2024-07-06|
# +-----------+---------------+--------------------+---+---------+----------+-----------------+
# only showing top 5 rows

# %%
print("Total records:", customers_bronze.count())
# Out:
# Total records: 12030

# %%
print(
    "Unique customer IDs:",
    customers_bronze.select("customer_id").distinct().count()
)
# Out:
# Unique customer IDs: 12000

# %%
customers_bronze.count()
# Out:
# 12030

# %%
customers_bronze.select("customer_id").distinct().count()
# Out:
# 12000

# %%
customers_silver = customers_bronze.dropDuplicates(["customer_id"])

# %%
print("Before:", customers_bronze.count())
print("After :", customers_silver.count())
# Out:
# Before: 12030
# After : 12000

# %%
customers_silver = customers_bronze.dropDuplicates(["customer_id"])

# %%
customers_bronze = spark.table("workspace.banking_bronze.customers")

# %%
customers_silver = customers_bronze.dropDuplicates(["customer_id"])

# %%
print("Before:", customers_bronze.count())
print("After :", customers_silver.count())
# Out:
# Before: 12030
# After : 12000

# %%
customers_bronze = spark.table("workspace.banking_bronze.customers")

# %%
customers_silver = customers_bronze.dropDuplicates(["customer_id"])

# %%
customers_bronze.dropDuplicates(["customer_id"])
# Out:
# DataFrame[customer_id: string, customer_name: string, email: string, age: int, city: string, state: string, registration_date: date]

# %%
customers_silver = customers_bronze.dropDuplicates(["customer_id"])

# %%
print("Before:", customers_bronze.count())
print("After :", customers_silver.count())
# Out:
# Before: 12030
# After : 12000

# %%
from pyspark.sql.functions import col, sum

customers_silver.select(
    sum(col("customer_id").isNull().cast("int")).alias("customer_id_nulls"),
    sum(col("customer_name").isNull().cast("int")).alias("name_nulls"),
    sum(col("email").isNull().cast("int")).alias("email_nulls"),
    sum(col("age").isNull().cast("int")).alias("age_nulls"),
    sum(col("city").isNull().cast("int")).alias("city_nulls"),
    sum(col("state").isNull().cast("int")).alias("state_nulls"),
    sum(col("registration_date").isNull().cast("int")).alias("date_nulls")
).show()
# Out:
# +-----------------+----------+-----------+---------+----------+-----------+----------+
# |customer_id_nulls|name_nulls|email_nulls|age_nulls|city_nulls|state_nulls|date_nulls|
# +-----------------+----------+-----------+---------+----------+-----------+----------+
# |                0|         0|         24|        0|        24|          0|         0|
# +-----------------+----------+-----------+---------+----------+-----------+----------+

# %%
from pyspark.sql.functions import coalesce, lit

customers_silver = customers_silver \
    .withColumn("email", coalesce(col("email"), lit("Unknown"))) \
    .withColumn("city", coalesce(col("city"), lit("Unknown")))

# %%
customers_silver.select(
    "customer_id",
    "email",
    "city"
).show(10)
# Out:
# +-----------+--------------------+---------+
# |customer_id|               email|     city|
# +-----------+--------------------+---------+
# |    C000001|customer000001@ex...|  Madurai|
# |    C000002|customer000002@ex...|    Kochi|
# |    C000003|customer000003@ex...|    Salem|
# |    C000004|customer000004@ex...| Thrissur|
# |    C000005|customer000005@ex...|New Delhi|
# |    C000006|customer000006@ex...|    Kochi|
# |    C000007|customer000007@ex...|New Delhi|
# |    C000008|customer000008@ex...| Warangal|
# |    C000009|customer000009@ex...|     Pune|
# |    C000010|customer000010@ex...| Warangal|
# +-----------+--------------------+---------+
# only showing top 10 rows

# %%
customers_silver.select(
    sum(col("email").isNull().cast("int")).alias("email_nulls"),
    sum(col("city").isNull().cast("int")).alias("city_nulls")
).show()
# Out:
# +-----------+----------+
# |email_nulls|city_nulls|
# +-----------+----------+
# |          0|         0|
# +-----------+----------+

# %%
coalesce(col("email"), lit("Unknown"))
# Out:
# Column<'coalesce(email, Unknown)'>

# %%
customers_silver.select(
    "age"
).describe().show()customers_silver.select(
    "age"
).describe().show()
# Out:
#   File <command-5927629789056567>, line 3
#     ).describe().show()customers_silver.select(
#                        ^
# SyntaxError: invalid syntax

# %%
from pyspark.sql.functions import col, coalesce, lit, sum

# %%
customers_silver = customers_silver.withColumn("email", coalesce(col("email"), lit("Unknown")))

# %%
customers_silver.select("customer_id", "email", "city").show(10)
# Out:
# +-----------+--------------------+---------+
# |customer_id|               email|     city|
# +-----------+--------------------+---------+
# |    C000001|customer000001@ex...|  Madurai|
# |    C000002|customer000002@ex...|    Kochi|
# |    C000003|customer000003@ex...|    Salem|
# |    C000004|customer000004@ex...| Thrissur|
# |    C000005|customer000005@ex...|New Delhi|
# |    C000006|customer000006@ex...|    Kochi|
# |    C000007|customer000007@ex...|New Delhi|
# |    C000008|customer000008@ex...| Warangal|
# |    C000009|customer000009@ex...|     Pune|
# |    C000010|customer000010@ex...| Warangal|
# +-----------+--------------------+---------+
# only showing top 10 rows

# %%
customers_silver.select(
    sum(col("email").isNull().cast("int")).alias("email_nulls"),
    sum(col("city").isNull().cast("int")).alias("city_nulls")
).show()
# Out:
# +-----------+----------+
# |email_nulls|city_nulls|
# +-----------+----------+
# |          0|         0|
# +-----------+----------+

# %%
customers_bronze = spark.table("workspace.banking_bronze.customers")

# %%
customers_silver = customers_bronze.dropDuplicates(["customer_id"])

# %%
from pyspark.sql.functions import col, coalesce, lit, sum

# %%
customers_silver = customers_silver.withColumn(
    "email",
    coalesce(col("email"), lit("Unknown"))
)

# %%
customers_silver = customers_silver.withColumn(
    "city",
    coalesce(col("city"), lit("Unknown"))
)

# %%
customers_silver.select("age").describe().show()
# Out:
# +-------+------------------+
# |summary|               age|
# +-------+------------------+
# |  count|             12000|
# |   mean|          46.21225|
# | stddev|16.501759268102663|
# |    min|                18|
# |    max|                74|
# +-------+------------------+

# %%
print(
    "Invalid age records:",
    customers_silver.filter(
        (col("age") < 18) | (col("age") > 100)
    ).count()
)
# Out:
# Invalid age records: 0
